# %%
## Importing data

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Mary\Desktop\Data Analyst CF\26.07.2021Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_47.pkl'))

# %%
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number   day_of_week          hour  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01  2.738867e+00  1.342515e+01
# std    9.872988e+05  5.946610e+04  1.753532e+01  2.090077e+00  4.246380e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00  1.000000e+00  1.000000e+01
# 50%    1.711049e+06  1.026160e+05  1.100000e+01  3.000000e+00  1.300000e+01
# 75%    2.565499e+06  1.543890e+05  2.400000e+01  5.000000e+00  1.600000e+01
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00  2.300000e+01
#
#        days_since_prior_order    product_id  add_to_cart_order     reordered  \
# count            3.032876e+07  3.240486e+07       3.240486e+07  3.240486e+07
# mean             1.110408e+01  2.559866e+04       8.352547e+00  5.895873e-01
# ...

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices exists    price_range_loc  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
# Create a subset called df of the first one million entries
df = ords_prods_merge[:1000000]

# %%
df.describe()
# Out:
#            order_id         user_id    order_number     day_of_week  \
# count  1.000000e+06  1000000.000000  1000000.000000  1000000.000000
# mean   1.710240e+06   101788.547547       18.731714        2.686741
# std    9.873682e+05    59011.894306       18.563841        2.053382
# min    5.000000e+00        1.000000        1.000000        0.000000
# 25%    8.555392e+05    50641.000000        5.000000        1.000000
# 50%    1.709734e+06   101164.000000       12.000000        2.000000
# 75%    2.565079e+06   152132.000000       27.000000        5.000000
# max    3.421068e+06   206209.000000       99.000000        6.000000
#
#                  hour  days_since_prior_order      product_id  \
# count  1000000.000000           939915.000000  1000000.000000
# mean        13.272235               10.646367    27119.966748
# std          4.218017                8.467237    15578.819637
# min          0.000000                0.000000      196.000000
# ...

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices exists    price_range_loc  \
# ...

# %%
df.shape
# Out:
# (1000000, 19)

# %%
#Create a group in the subset
df.groupby('product_name')

# %%
# Aggregate function inside the grouping. Calculate the mean of order_number, grouped by department_id
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
#Aggregate function without agg(), with mean()
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Multiple Aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
# Verifying Loyalty. 
#1. Split the data into groups based on the “user_id” column
ords_prods_merge.groupby('user_id')

# %%
# Apply the transform() function on the “order_number” column to generate the maximum orders for each user. Create a new column, “max_order,” into which you’ll place the results of your aggregation.
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0    2539329        1    prior             1            2     8
# 1    2398795        1    prior             2            3     7
# 2     473747        1    prior             3            3    12
# 3    2254736        1    prior             4            4     7
# 4     431534        1    prior             5            4    15
# 5    3367565        1    prior             6            2     7
# 6     550135        1    prior             7            1     9
# 7    3108588        1    prior             8            1    14
# 8    2295261        1    prior             9            1    16
# 9    2550362        1    prior            10            4     8
# 10   2968173       15    prior            15            1     9
# 11   1870022       15    prior            17            2    16
# 12   1911383       15    prior            18            2    11
# 13   2715276       15    prior            21            1     9
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 20)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0    2539329        1    prior             1            2     8
# 1    2398795        1    prior             2            3     7
# 2     473747        1    prior             3            3    12
# 3    2254736        1    prior             4            4     7
# 4     431534        1    prior             5            4    15
# ..       ...      ...      ...           ...          ...   ...
# 95   3226575      360    prior             1            5    12
# 96   1469869      377    prior             3            5    17
# 97   1927023      387    prior             2            4    10
# 98    858092      420    prior             4            1    19
# 99    119314      420    prior             5            3    19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                  1          0   both
# ...

# %%
# not to assign any options regarding the maximum number of rows to display
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0    2539329        1    prior             1            2     8
# 1    2398795        1    prior             2            3     7
# 2     473747        1    prior             3            3    12
# 3    2254736        1    prior             4            4     7
# 4     431534        1    prior             5            4    15
# 5    3367565        1    prior             6            2     7
# 6     550135        1    prior             7            1     9
# 7    3108588        1    prior             8            1    14
# 8    2295261        1    prior             9            1    16
# 9    2550362        1    prior            10            4     8
# 10   2968173       15    prior            15            1     9
# 11   1870022       15    prior            17            2    16
# 12   1911383       15    prior            18            2    11
# 13   2715276       15    prior            21            1     9
# ...

# %%
#Stablishing the frequency of purchases by loyalty
ords_prods_merge.loc[ords_prods_merge['max_order']>40, 'loyalty_flag'] = 'Loyal Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular Customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New Customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   product_name aisle_id  department_id  prices  exists    price_range_loc  \
# ...

# %%
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number   day_of_week          hour  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01  2.738867e+00  1.342515e+01
# std    9.872988e+05  5.946610e+04  1.753532e+01  2.090077e+00  4.246380e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00  1.000000e+00  1.000000e+01
# 50%    1.711049e+06  1.026160e+05  1.100000e+01  3.000000e+00  1.300000e+01
# 75%    2.565499e+06  1.543890e+05  2.400000e+01  5.000000e+00  1.600000e+01
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00  2.300000e+01
#
#        days_since_prior_order    product_id  add_to_cart_order     reordered  \
# count            3.032876e+07  3.240486e+07       3.240486e+07  3.240486e+07
# mean             1.110408e+01  2.559866e+04       8.352547e+00  5.895873e-01
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
# first 60 rows of user_id, loyalty_flag, order_number
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New Customer             1
# 1         1      New Customer             2
# 2         1      New Customer             3
# 3         1      New Customer             4
# 4         1      New Customer             5
# 5         1      New Customer             6
# 6         1      New Customer             7
# 7         1      New Customer             8
# 8         1      New Customer             9
# 9         1      New Customer            10
# 10       15  Regular Customer            15
# 11       15  Regular Customer            17
# 12       15  Regular Customer            18
# 13       15  Regular Customer            21
# 14       15  Regular Customer            22
# 15       19      New Customer             2
# 16       19      New Customer             5
# 17       19      New Customer             7
# 18       21  Regular Customer            10
# 19       31  Regular Customer            10
# ...

# %%
# Export as a pickle 
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods48.pkl'))
