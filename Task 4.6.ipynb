# %%
## Importing data

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Mary\Desktop\Data Analyst CF\26.07.2021Instacart Basket Analysis'

# %%
df_orders_products_combined = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.csv'), index_col = False)

# %%
df_orders_products_combined.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number   day_of_week  \
# count  3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07
# mean   1.621724e+07  1.710749e+06  1.029372e+05  1.714205e+01  2.738818e+00
# std    9.363031e+06  9.873007e+05  5.946648e+04  1.753504e+01  2.090049e+00
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.108622e+06  8.559430e+05  5.142100e+04  5.000000e+00  1.000000e+00
# 50%    1.621724e+07  1.711048e+06  1.026110e+05  1.100000e+01  3.000000e+00
# 75%    2.432587e+07  2.565514e+06  1.543910e+05  2.400000e+01  5.000000e+00
# max    3.243449e+07  3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00
#
#                hour  days_since_prior_order    product_id  add_to_cart_order  \
# count  3.243449e+07            3.035642e+07  3.243449e+07       3.243449e+07
# mean   1.342498e+01            1.110407e+01  2.557634e+04       8.351076e+00
# ...

# %%
del df_orders_products_combined['Unnamed: 0']

# %%
df_orders_products_combined.describe()
# Out:
#            order_id       user_id  order_number   day_of_week          hour  \
# count  3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07  3.243449e+07
# mean   1.710749e+06  1.029372e+05  1.714205e+01  2.738818e+00  1.342498e+01
# std    9.873007e+05  5.946648e+04  1.753504e+01  2.090049e+00  4.246365e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.559430e+05  5.142100e+04  5.000000e+00  1.000000e+00  1.000000e+01
# 50%    1.711048e+06  1.026110e+05  1.100000e+01  3.000000e+00  1.300000e+01
# 75%    2.565514e+06  1.543910e+05  2.400000e+01  5.000000e+00  1.600000e+01
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00  2.300000e+01
#
#        days_since_prior_order    product_id  add_to_cart_order     reordered
# count            3.035642e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean             1.110407e+01  2.557634e+04       8.351076e+00  5.896975e-01
# ...

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2539329        1    prior             1            2     8
# 2   2539329        1    prior             1            2     8
# 3   2539329        1    prior             1            2     8
# 4   2539329        1    prior             1            2     8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_prods_clean_no_dups = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_prods_clean_no_dups.csv'), index_col = False)

# %%
df_prods_clean_no_dups.describe()
# Out:
#          Unnamed: 0    product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24852.005053  24850.349775     67.762442      11.728942      9.993282
# std    14342.265579  14340.705287     38.315784       5.850779    453.615536
# min        0.000000      1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000  12432.750000     35.000000       7.000000      4.100000
# 50%    24851.500000  24850.500000     69.000000      13.000000      7.100000
# 75%    37272.250000  37268.250000    100.000000      17.000000     11.100000
# max    49692.000000  49688.000000    134.000000      21.000000  99999.000000

# %%
del df_prods_clean_no_dups['Unnamed: 0']

# %%
df_prods_clean_no_dups.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49672.000000  49672.000000   49672.000000  49672.000000
# mean   24850.349775     67.762442      11.728942      9.993282
# std    14340.705287     38.315784       5.850779    453.615536
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12432.750000     35.000000       7.000000      4.100000
# 50%    24850.500000     69.000000      13.000000      7.100000
# 75%    37268.250000    100.000000      17.000000     11.100000
# max    49688.000000    134.000000      21.000000  99999.000000

# %%
df_prods_clean_no_dups.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods_clean_no_dups.shape
# Out:
# (49672, 5)

# %%
df_orders_products_merged = df_orders_products_combined.merge(df_prods_clean_no_dups, on = 'product_id', indicator = 'exists')

# %%
df_orders_products_merged.describe()
# Out:
#            order_id       user_id  order_number   day_of_week          hour  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01  2.738867e+00  1.342515e+01
# std    9.872988e+05  5.946610e+04  1.753532e+01  2.090077e+00  4.246380e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00  1.000000e+00  1.000000e+01
# 50%    1.711049e+06  1.026160e+05  1.100000e+01  3.000000e+00  1.300000e+01
# 75%    2.565499e+06  1.543890e+05  2.400000e+01  5.000000e+00  1.600000e+01
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00  2.300000e+01
#
#        days_since_prior_order    product_id  add_to_cart_order     reordered  \
# count            3.032876e+07  3.240486e+07       3.240486e+07  3.240486e+07
# mean             1.110408e+01  2.559866e+04       8.352547e+00  5.895873e-01
# ...

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices exists
# 0         Soda        77              7     9.0   both
# ...

# %%
df_orders_products_merged.shape
# Out:
# (32404859, 16)

# %%
# Export data to csv

df_orders_products_merged.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.csv'))

# %%
# Export data to pkl

df_orders_products_merged(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
