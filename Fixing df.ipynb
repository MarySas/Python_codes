# %%
## Importing data

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Mary\Desktop\Data Analyst CF\26.07.2021Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_task_48.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#      price_range_loc  busiest_days  busiest_period_of_day  max_order  \
# 0  Mid-range product  Regular days         Average orders         10
# ...

# %%
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number   day_of_week          hour  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01  2.738867e+00  1.342515e+01
# std    9.872988e+05  5.946610e+04  1.753532e+01  2.090077e+00  4.246380e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00  1.000000e+00  1.000000e+01
# 50%    1.711049e+06  1.026160e+05  1.100000e+01  3.000000e+00  1.300000e+01
# 75%    2.565499e+06  1.543890e+05  2.400000e+01  5.000000e+00  1.600000e+01
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00  2.300000e+01
#
#        days_since_prior_order    product_id  add_to_cart_order     reordered  \
# count            3.032876e+07  3.240486e+07       3.240486e+07  3.240486e+07
# mean             1.110408e+01  2.559866e+04       8.352547e+00  5.895873e-01
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 26)

# %%
# Change Nan values in days_since_prior_order
ords_prods_merge['days_since_prior_order'] = ords_prods_merge['days_since_prior_order'].replace(np.nan, 0)

# %%
ords_prods_merge.head(60)
# Out:
#     order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0    2539329        1    prior             1            2     8
# 1    2398795        1    prior             2            3     7
# 2     473747        1    prior             3            3    12
# 3    2254736        1    prior             4            4     7
# 4     431534        1    prior             5            4    15
# 5    3367565        1    prior             6            2     7
# 6     550135        1    prior             7            1     9
# 7    3108588        1    prior             8            1    14
# 8    2295261        1    prior             9            1    16
# 9    2550362        1    prior            10            4     8
# 10   2968173       15    prior            15            1     9
# 11   1870022       15    prior            17            2    16
# 12   1911383       15    prior            18            2    11
# 13   2715276       15    prior            21            1     9
# ...

# %%
# deleting frequency flag and new_column_flagname

# %%
del ords_prods_merge['frequency_flag']

# %%
del ords_prods_merge['new_column_flagname']

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     0.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   prices exists    price_range_loc  busiest_days  busiest_period_of_day  \
# ...

# %%
#Task 4.8.7 Create a frequency flag using median of days_since_prior_order
#First transform the data in mean, and create a column with the value

# %%
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order']>20, 'new_column_flagname'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] <= 20) & (ords_prods_merge['median_days_since_prior_order'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order']<=10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check the frequency_flag
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer    22796659
# Regular customer      6921472
# NaN                   2686728
# Name: frequency_flag, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     0.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#      price_range_loc  busiest_days  busiest_period_of_day  max_order  \
# 0  Mid-range product  Regular days         Average orders         10
# ...

# %%
del ords_prods_merge['mean_days_since_prior_order']

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     0.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   exists    price_range_loc  busiest_days  busiest_period_of_day  max_order  \
# ...

# %%
del ords_prods_merge['new_column_flagname']

# %%
del ords_prods_merge['frequency_flag']

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order']>20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order'] <= 20) & (ords_prods_merge['median_days_since_prior_order'] > 10), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order']<=10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0   2539329        1    prior             1            2     8
# 1   2398795        1    prior             2            3     7
# 2    473747        1    prior             3            3    12
# 3   2254736        1    prior             4            4     7
# 4    431534        1    prior             5            4    15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     0.0         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   prices exists    price_range_loc  busiest_days  busiest_period_of_day  \
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0    2539329        1    prior             1            2     8
# 1    2398795        1    prior             2            3     7
# 2     473747        1    prior             3            3    12
# 3    2254736        1    prior             4            4     7
# 4     431534        1    prior             5            4    15
# ..       ...      ...      ...           ...          ...   ...
# 95   3226575      360    prior             1            5    12
# 96   1469869      377    prior             3            5    17
# 97   1927023      387    prior             2            4    10
# 98    858092      420    prior             4            1    19
# 99    119314      420    prior             5            3    19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                      0.0         196                  1          0  ...
# ...

# %%
ords_prods_merge['Nan'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nan'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-15da7245d9ba> in <module>
# ...

# %%
ords_prods_merge['nan'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nan'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-bb2507c8a152> in <module>
# ...

# %%
ords_prods_merge.describe()
# Out:
#            order_id       user_id  order_number   day_of_week          hour  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01  2.738867e+00  1.342515e+01
# std    9.872988e+05  5.946610e+04  1.753532e+01  2.090077e+00  4.246380e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00  1.000000e+00  1.000000e+01
# 50%    1.711049e+06  1.026160e+05  1.100000e+01  3.000000e+00  1.300000e+01
# 75%    2.565499e+06  1.543890e+05  2.400000e+01  5.000000e+00  1.600000e+01
# max    3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00  2.300000e+01
#
#        days_since_prior_order    product_id  add_to_cart_order     reordered  \
# count            3.240486e+07  3.240486e+07       3.240486e+07  3.240486e+07
# mean             1.039267e+01  2.559866e+04       8.352547e+00  5.895873e-01
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0    2539329        1    prior             1            2     8
# 1    2398795        1    prior             2            3     7
# 2     473747        1    prior             3            3    12
# 3    2254736        1    prior             4            4     7
# 4     431534        1    prior             5            4    15
# ..       ...      ...      ...           ...          ...   ...
# 95   3226575      360    prior             1            5    12
# 96   1469869      377    prior             3            5    17
# 97   1927023      387    prior             2            4    10
# 98    858092      420    prior             4            1    19
# 99    119314      420    prior             5            3    19
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                      0.0         196                  1          0  ...
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  day_of_week  hour  \
# 0    2539329        1    prior             1            2     8
# 1    2398795        1    prior             2            3     7
# 2     473747        1    prior             3            3    12
# 3    2254736        1    prior             4            4     7
# 4     431534        1    prior             5            4    15
# 5    3367565        1    prior             6            2     7
# 6     550135        1    prior             7            1     9
# 7    3108588        1    prior             8            1    14
# 8    2295261        1    prior             9            1    16
# 9    2550362        1    prior            10            4     8
# 10   2968173       15    prior            15            1     9
# 11   1870022       15    prior            17            2    16
# 12   1911383       15    prior            18            2    11
# 13   2715276       15    prior            21            1     9
# ...

# %%
# Export as a pickle 
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_task_48.pkl'))
